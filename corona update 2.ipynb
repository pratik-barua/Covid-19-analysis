# %%
import pandas as pd
import matplotlib as plt
from matplotlib import pyplot
pyplot.style.use('ggplot')

# %%
#file path
path="C:\\Users\\user\\Desktop\\Projects\\Corona update analysis\\covid19_area.csv"
#importin csv file
df=pd.read_csv(path)
#printing csv file
df.head()
# Out:
#     Latitude  Longitude         Location  I_number
# 0  23.777176  90.339452            Dhaka       974
# 1  23.810500  90.337200  Dhaka(district)        40
# 2  23.999941  90.420273          Gazipur       173
# 3  24.433123  90.786568      Kishoreganj        77
# 4  23.239300  90.187000        Madaripur        25

# %%
df.set_index('Location',inplace=True)
df['I_number'].plot(kind='pie',
                            figsize=(15, 10),
                            autopct='%1.1f%%', 
                            pctdistance=1.06,    
                            startangle=90,     
                            shadow=True,
                            labels=None     
                            )

pyplot.title('Distribution of patient according to Location')
pyplot.axis('equal') # Sets the pie chart to look like a circle.
pyplot.legend(labels=df.index, loc='upper right') 
pyplot.show()

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
from PIL import Image # converting images into arrays
import matplotlib.patches as mpatches

# %%
total_values = sum(df['I_number'])
category_proportions = [(float(value) / total_values) for value in df['I_number']]

# print out proportions
for i, proportion in enumerate(category_proportions):
    print (df.index.values[i] + ': ' + str(proportion))
# Out:
# Dhaka: 0.4532340623545835
# Dhaka(district): 0.018613308515588647
# Gazipur: 0.0805025593299209
# Kishoreganj: 0.035830618892508145
# Madaripur: 0.011633317822242903
# Manikganj: 0.002791996277338297
# Narayanganj: 0.17961842717543045
# Munshiganj: 0.015355979525360632
# Narshingdi: 0.048859934853420196
# Rajbari: 0.003257328990228013
# Tangail: 0.004653327128897162
# Shariatpur: 0.003257328990228013
# Gopalgonj: 0.009771986970684038
# Faridpur: 0.0018613308515588647
# Chattogram: 0.01814797580269893
# Cox's Bazar: 0.00046533271288971617
# Cumilla: 0.008841321544904607
# B. Baria: 0.005118659841786877
# Laxmipur: 0.009771986970684038
# Bandarban: 0.00046533271288971617
# Noakhali: 0.0013959981386691485
# Feni: 0.0009306654257794323
# Chandpur: 0.0037226617031177293
# MouloviBazar: 0.0009306654257794323
# Shunamgonj: 0.00046533271288971617
# Hobigonj: 0.00046533271288971617
# Sylhet: 0.0013959981386691485
# Rangpur: 0.0013959981386691485
# Gaibandha: 0.005583992554676594
# ...

# %%
width = 70 # width of chart
height = 30 # height of chart

total_num_tiles = width * height # total number of tiles

print ('Total number of tiles is ', total_num_tiles)
# Out:
# Total number of tiles is  2100

# %%
# compute the number of tiles for each catagory
tiles_per_category = [round(proportion * total_num_tiles) for proportion in category_proportions]

# print out number of tiles per category
for i, tiles in enumerate(tiles_per_category):
    print (df.index.values[i] + ': ' + str(tiles))
# Out:
# Dhaka: 952
# Dhaka(district): 39
# Gazipur: 169
# Kishoreganj: 75
# Madaripur: 24
# Manikganj: 6
# Narayanganj: 377
# Munshiganj: 32
# Narshingdi: 103
# Rajbari: 7
# Tangail: 10
# Shariatpur: 7
# Gopalgonj: 21
# Faridpur: 4
# Chattogram: 38
# Cox's Bazar: 1
# Cumilla: 19
# B. Baria: 11
# Laxmipur: 21
# Bandarban: 1
# Noakhali: 3
# Feni: 2
# Chandpur: 8
# MouloviBazar: 2
# Shunamgonj: 1
# Hobigonj: 1
# Sylhet: 3
# Rangpur: 3
# Gaibandha: 12
# Nilphamari: 9
# Lalmonirhat: 2
# Kurigram: 2
# Dinajpur: 10
# Panchagar: 1
# Thakurgaon: 6
# Khulna: 1
# Jessore: 1
# Bagerhat: 1
# Narail: 2
# Chuadanga: 1
# Mymensingh: 21
# Jamalpur: 20
# Netrokona: 14
# Sherpur: 11
# Barguna: 10
# Barishal: 21
# Patuakhali: 2
# Pirojpur: 4
# Jhalokathi: 4
# Joypurhat: 2
# Pabna: 2
# Bogra: 1
# Rajshahi: 4
# Naogaon: 1
# Sirajganj: 1

# %%
# initialize the waffle chart as an empty matrix
waffle_chart = np.zeros((height, width))

# define indices to loop through waffle chart
category_index = 0
tile_index = 0

# populate the waffle chart
for col in range(width):
    for row in range(height):
        tile_index += 1

        # if the number of tiles populated for the current category is equal to its corresponding allocated tiles...
        if tile_index > sum(tiles_per_category[0:category_index]):
            # ...proceed to the next category
            category_index += 1       
            
        # set the class value to an integer, which increases with class
        waffle_chart[row, col] = category_index
        
print ('Waffle chart populated!')
# Out:
# Waffle chart populated!

# %%
waffle_chart
# Out:
# array([[ 1.,  1.,  1., ..., 42., 43., 46.],
#        [ 1.,  1.,  1., ..., 42., 43., 46.],
#        [ 1.,  1.,  1., ..., 42., 43., 46.],
#        ...,
#        [ 1.,  1.,  1., ..., 43., 46., 51.],
#        [ 1.,  1.,  1., ..., 43., 46., 51.],
#        [ 1.,  1.,  1., ..., 43., 46., 52.]])

# %%
# instantiate a new figure object
fig = pyplot.figure()

# use matshow to display the waffle chart
colormap = pyplot.cm.coolwarm
pyplot.matshow(waffle_chart, cmap=colormap)
pyplot.colorbar()

# %%
# instantiate a new figure object
fig = pyplot.figure()

# use matshow to display the waffle chart
colormap = pyplot.cm.coolwarm
pyplot.matshow(waffle_chart, cmap=colormap)
pyplot.colorbar()

# get the axis
ax = pyplot.gca()

# set minor ticks
ax.set_xticks(np.arange(-.5, (width), 1), minor=True)
ax.set_yticks(np.arange(-.5, (height), 1), minor=True)
    
# add gridlines based on minor ticks
ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

pyplot.xticks([])
pyplot.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed and imported!')
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Folium installed and imported!

# %%
# %matplotlib inline
bd_latitude = 23.6850
bd_longitude = 90.3563

bd_map = folium.Map(location=[bd_latitude, bd_longitude], zoom_start=7)
# loop through the 100 crimes and add each to the incidents feature group
for lat, lng,num in zip(df.Latitude, df.Longitude,df.I_number):
    
        folium.CircleMarker(
            [lat, lng],
            radius=np.log(num*100), # define how big you want the circle markers to be
            color='yellow',
            fill=True,
            popup=str(num),
            fill_color='red',
            fill_opacity=0.6
            
        ).add_to(bd_map)
    # add incidents to map
bd_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
